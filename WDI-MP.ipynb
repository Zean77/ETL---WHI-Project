# %%
# Dependencies
import pandas as pd
import psycopg2

from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from config import pgkey

con_string = f"postgresql+psycopg2://postgres:{pgkey}@localhost:5432/ETL_DB"
engine = create_engine(con_string)
connection = engine.connect()

# %%
# Make a reference to the file path
WDI_path = "Resources/WDI_Selected_data.xlsx"

# Import the file as a DataFrame
WDI_path_df = pd.read_excel(WDI_path)
WDI_path_df.head()
# Out:
#                      Country Name Country Code  \
# 0                      Arab World          ARB
# 1          Caribbean small states          CSS
# 2  Central Europe and the Baltics          CEB
# 3      Early-demographic dividend          EAR
# 4             East Asia & Pacific          EAS
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD   NaN
# 1  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD   NaN
# 2  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD   NaN
# 3  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD   NaN
# 4  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD   NaN
#
#    1961  1962  1963  1964  1965  ...          2011          2012  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   5389.100161   5892.763208
# 1   NaN   NaN   NaN   NaN   NaN  ...   7478.631998   7877.721696
# ...

# %%
#Select 2018 data
data = WDI_path_df[["Country Name", "Country Code", "Indicator Name", "Indicator Code", "2018"]]
data.head()
data.count()
# Out:
# Country Name      264
# Country Code      264
# Indicator Name    264
# Indicator Code    264
# 2018              213
# dtype: int64

# %%
#Remove NaN
clean_WDI_df = data[data['2018'].notna()]
clean_WDI_df.head()
# Out:
#                      Country Name Country Code  \
# 0                      Arab World          ARB
# 1          Caribbean small states          CSS
# 2  Central Europe and the Baltics          CEB
# 3      Early-demographic dividend          EAR
# 4             East Asia & Pacific          EAS
#
#                                       Indicator Name     Indicator Code  \
# 0  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 1  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 2  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 3  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 4  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
#
#            2018
# 0   5416.267637
# 1   7831.168974
# 2  12834.069066
# 3   2988.962642
# 4   8943.136341

# %%
clean_WDI_MP_df.rename(columns = {'Country Name':'stats_country', '2018':'stats_year', 
                              'Indicator Name':'WDI_income_per_capita'}, inplace = True)
clean_WDI_MP_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-596dc753b780> in <module>
# ----> 1 clean_WDI_MP_df.rename(columns = {'Country Name':'stats_country', '2018':'stats_year',
#       2                               'Indicator Name':'WDI_income_per_capita'}, inplace = True)
#       3 clean_WDI_MP_df.head()
#
# NameError: name 'clean_WDI_MP_df' is not defined

# %%
# Load combined data into database
clean_WDI_MP_df.to_sql('country_stats', con=engine)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5ceaeafa44ae> in <module>
#       1 # Load combined data into database
# ----> 2 clean_WDI_MP_df.to_sql('country_stats', con=engine)
#
# NameError: name 'clean_WDI_MP_df' is not defined
